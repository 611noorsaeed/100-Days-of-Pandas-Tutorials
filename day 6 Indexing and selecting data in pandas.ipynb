# %%
import pandas as pd

# %%
df = pd.read_csv("Bank Customer Churn Prediction.csv")

# %%
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %% [markdown]
# # Selecting Single Column

# %%
age = df['age']

# %%
age
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: age, Length: 10000, dtype: int64

# %% [markdown]
# # select multiple columns

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %%
df[['credit_score','country','gender']]
# Out:
#       credit_score  country  gender
# 0              619   France  Female
# 1              608    Spain  Female
# 2              502   France  Female
# 3              699   France  Female
# 4              850    Spain  Female
# ...            ...      ...     ...
# 9995           771   France    Male
# 9996           516   France    Male
# 9997           709   France  Female
# 9998           772  Germany    Male
# 9999           792   France  Female
#
# [10000 rows x 3 columns]

# %% [markdown]
# # Filter and select customers who are females and their credit
# # score greater than 700.

# %%
filtered_df = df[(df['gender'] == 'Female') & (df['credit_score'] > 700)][['gender','age','credit_score']]
print("Filtered Data:")
print(filtered_df)
# Out:
# Filtered Data:
#       gender  age  credit_score
# 4     Female   43           850
# 19    Female   24           726
# 24    Female   38           846
# 34    Female   29           722
# 43    Female   49           834
# ...      ...  ...           ...
# 9960  Female   33           795
# 9971  Female   34           833
# 9994  Female   29           800
# 9997  Female   36           709
# 9999  Female   28           792
#
# [1415 rows x 3 columns]

# %% [markdown]
# # Selecting specific columns by their names.

# %%
# df['credit_card']
# df.age
df['credit_score']
# Out:
# 0       619
# 1       608
# 2       502
# 3       699
# 4       850
#        ...
# 9995    771
# 9996    516
# 9997    709
# 9998    772
# 9999    792
# Name: credit_score, Length: 10000, dtype: int64

# %% [markdown]
# # Filtering rows based on specific conditions.

# %%
df.head(3)
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1

# %%
df[df['country'] == 'France']
# Out:
#       customer_id  credit_score country  gender  age  tenure    balance  \
# 0        15634602           619  France  Female   42       2       0.00
# 2        15619304           502  France  Female   42       8  159660.80
# 3        15701354           699  France  Female   39       1       0.00
# 6        15592531           822  France    Male   50       7       0.00
# 8        15792365           501  France    Male   44       4  142051.07
# ...           ...           ...     ...     ...  ...     ...        ...
# 9994     15719294           800  France  Female   29       2       0.00
# 9995     15606229           771  France    Male   39       5       0.00
# 9996     15569892           516  France    Male   35      10   57369.61
# 9997     15584532           709  France  Female   36       7       0.00
# 9999     15628319           792  France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df[(df['country'] == 'France') & (df['active_member'] == 1)]
# Out:
#       customer_id  credit_score country  gender  age  tenure    balance  \
# 0        15634602           619  France  Female   42       2       0.00
# 6        15592531           822  France    Male   50       7       0.00
# 8        15792365           501  France    Male   44       4  142051.07
# 9        15592389           684  France    Male   27       2  134603.88
# 19       15568982           726  France  Female   24       6       0.00
# ...           ...           ...     ...     ...  ...     ...        ...
# 9973     15806455           611  France    Male   27       7       0.00
# 9977     15579969           683  France  Female   32       9       0.00
# 9979     15692664           677  France  Female   58       1   90022.85
# 9996     15569892           516  France    Male   35      10   57369.61
# 9997     15584532           709  France  Female   36       7       0.00
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
print(df[(df['gender'] == 'Male') & (df['balance'] > 140000)])
# Out:
#       customer_id  credit_score  country gender  age  tenure    balance  \
# 8        15792365           501   France   Male   44       4  142051.07
# 15       15643966           616  Germany   Male   45       3  143129.41
# 36       15788448           490    Spain   Male   31       3  145260.23
# 51       15768193           585  Germany   Male   36       5  146050.97
# 95       15699461           515    Spain   Male   35      10  176273.95
# ...           ...           ...      ...    ...  ...     ...        ...
# 9972     15747927           758   France   Male   26       4  155739.76
# 9981     15672754           498  Germany   Male   42       3  152039.70
# 9986     15581736           673  Germany   Male   47       1  183579.54
# 9987     15588839           606    Spain   Male   30       8  180307.73
# 9993     15569266           644   France   Male   28       7  155060.41
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %% [markdown]
# # Selecting specific rows or columns using labels with loc.

# %%
df.head(3)
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1

# %%
# df.loc[0]
df.loc[0][['country']]
# Out:
# country    France
# Name: 0, dtype: object

# %%
df.loc[1]['balance']
# Out:
# 83807.86

# %%
# df.loc[0,'credit_score':'balance']
df.loc[1:3,'credit_score':'age']
# Out:
#    credit_score country  gender  age
# 1           608   Spain  Female   41
# 2           502  France  Female   42
# 3           699  France  Female   39

# %%
df.head(3)
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1

# %%
df.loc[[0,1,2],['credit_score','country','gender']]
# Out:
#    credit_score country  gender
# 0           619  France  Female
# 1           608   Spain  Female
# 2           502  France  Female

# %%
# Selecting all of the rows and some columns
df.loc[:,['age','gender','country']]
# Out:
#       age  gender  country
# 0      42  Female   France
# 1      41  Female    Spain
# 2      42  Female   France
# 3      39  Female   France
# 4      43  Female    Spain
# ...   ...     ...      ...
# 9995   39    Male   France
# 9996   35    Male   France
# 9997   36  Female   France
# 9998   42    Male  Germany
# 9999   28  Female   France
#
# [10000 rows x 3 columns]

# %% [markdown]
# # Slicing data based on label ranges with loc

# %%
df.tail(3)
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# 9997                1            0              1          42085.58      1
# 9998                2            1              0          92888.52      1
# 9999                1            1              0          38190.78      0

# %%
df.loc[9997:]
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# 9997                1            0              1          42085.58      1
# 9998                2            1              0          92888.52      1
# 9999                1            1              0          38190.78      0

# %%
df.loc[100:]
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 100      15808582           665   France  Female   40       6       0.00
# 101      15743192           623   France  Female   44       6       0.00
# 102      15580146           738   France    Male   31       9   82674.15
# 103      15776605           528    Spain    Male   36       7       0.00
# 104      15804919           670    Spain  Female   65       1       0.00
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df.head(4)

# %%
df.loc[0:2]

# %% [markdown]
# # Selecting specific rows or columns using integer-based positions with iloc

# %%
df.head(8)
# Out:
#    customer_id  credit_score  country  gender  age  tenure    balance  \
# 0     15634602           619   France  Female   42       2       0.00
# 1     15647311           608    Spain  Female   41       1   83807.86
# 2     15619304           502   France  Female   42       8  159660.80
# 3     15701354           699   France  Female   39       1       0.00
# 4     15737888           850    Spain  Female   43       2  125510.82
# 5     15574012           645    Spain    Male   44       8  113755.78
# 6     15592531           822   France    Male   50       7       0.00
# 7     15656148           376  Germany  Female   29       4  115046.74
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# ...

# %%
# Selecting all of the rows and some columns
df.iloc[[3,4,5],[1,2,3]]
# Out:
#    credit_score country  gender
# 3           699  France  Female
# 4           850   Spain  Female
# 5           645   Spain    Male

# %%
df.iloc[[4,5,6],3]
# Out:
# 4    Female
# 5      Male
# 6      Male
# Name: gender, dtype: object

# %%
# retrieving all rows and some columns by iloc method 
df.iloc [:, [1, 2]]
# Out:
#       credit_score  country
# 0              619   France
# 1              608    Spain
# 2              502   France
# 3              699   France
# 4              850    Spain
# ...            ...      ...
# 9995           771   France
# 9996           516   France
# 9997           709   France
# 9998           772  Germany
# 9999           792   France
#
# [10000 rows x 2 columns]

# %%
df.head(1)
# Out:
#    customer_id  credit_score country  gender  age  tenure  balance  \
# 0     15634602           619  France  Female   42       2      0.0
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1

# %%
df.iloc[:,-1]
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: churn, Length: 10000, dtype: int64

# %%
df.iloc[1:3,-2]
# Out:
# 1    112542.58
# 2    113931.57
# Name: estimated_salary, dtype: float64

# %%
df.head(1)
# Out:
#    customer_id  credit_score country  gender  age  tenure  balance  \
# 0     15634602           619  France  Female   42       2      0.0
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1

# %%
df.iloc[1:3,0:4]

# %%
df.iloc[1,1]

# %% [markdown]
# # Slicing data based on integer ranges with iloc.

# %%
df.iloc[40:100]
# Out:
#     customer_id  credit_score  country  gender  age  tenure    balance  \
# 40     15619360           472    Spain    Male   40       4       0.00
# 41     15738148           465   France  Female   51       8  122522.32
# 42     15687946           556   France  Female   61       2  117419.35
# 43     15755196           834   France  Female   49       2  131394.56
# 44     15684171           660    Spain  Female   61       5  155931.11
# 45     15754849           776  Germany  Female   32       4  109421.13
# 46     15602280           829  Germany  Female   27       9  112045.67
# 47     15771573           637  Germany  Female   39       9  137843.80
# 48     15766205           550  Germany    Male   38       2  103391.38
# 49     15771873           776  Germany  Female   37       2  103769.22
# 50     15616550           698  Germany    Male   44      10  116363.37
# 51     15768193           585  Germany    Male   36       5  146050.97
# ...

# %% [markdown]
# #  Extracting specific values from a DataFrame using at, iat, or values.

# %%
df.head(2)
# Out:
#    customer_id  credit_score country  gender  age  tenure   balance  \
# 0     15634602           619  France  Female   42       2      0.00
# 1     15647311           608   Spain  Female   41       1  83807.86
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0

# %%
df.at[1,'credit_score']
# Out:
# 608

# %%
df.iat[0,1]
# Out:
# 619

# %%
df.iat[0,3]
# Out:
# 'Female'

# %% [markdown]
# # Accessing data at different levels of a MultiIndex

# %%
# Creating a DataFrame with MultiIndex columns
data = {
    ('Group 1', 'A'): [1, 2, 3],
    ('Group 1', 'B'): [4, 5, 6],
    ('Group 2', 'C'): [7, 8, 9],
    ('Group 2', 'D'): [10, 11, 12]
}
df = pd.DataFrame(data)
df.columns.names = ['Group', 'Subgroup']
df
# Out:
# Group    Group 1    Group 2
# Subgroup       A  B       C   D
# 0              1  4       7  10
# 1              2  5       8  11
# 2              3  6       9  12

# %%
df['Group 1']
# Out:
# Subgroup  A  B
# 0         1  4
# 1         2  5
# 2         3  6

# %%
df['Group 2']
# Out:
# Subgroup  C   D
# 0         7  10
# 1         8  11
# 2         9  12

# %%
df['Group 1']['A']
# Out:
# 0    1
# 1    2
# 2    3
# Name: A, dtype: int64

# %%
df.loc[:,('Group 1', 'B')]
# Out:
# 0    4
# 1    5
# 2    6
# Name: (Group 1, B), dtype: int64

# %%
df.loc[:, ('Group 2', 'C'):('Group 2', 'D')]
# Out:
# Group    Group 2
# Subgroup       C   D
# 0              7  10
# 1              8  11
# 2              9  12
